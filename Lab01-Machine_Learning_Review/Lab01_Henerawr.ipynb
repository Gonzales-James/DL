# %% [markdown]
# <a href="https://colab.research.google.com/github/Gonzales-James/DL/blob/main/Lab01-Machine_Learning_Review/Lab01_Henerawr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
iris = pd.read_csv('/content/iris.data') # iris dataset
iris.columns = ['Sepal length (cm)', 'Sepal width (cm)', 'Petal length (cm)', 'Petal width (cm)', 'Iris_species']
iris_feat = iris.iloc[:,:-1]
iris_species = iris.iloc[:,-1]

# %%
iris
# Out:
#      Sepal length (cm)  Sepal width (cm)  ...  Petal width (cm)    Iris_species
# 0                  4.9               3.0  ...               0.2     Iris-setosa
# 1                  4.7               3.2  ...               0.2     Iris-setosa
# 2                  4.6               3.1  ...               0.2     Iris-setosa
# 3                  5.0               3.6  ...               0.2     Iris-setosa
# 4                  5.4               3.9  ...               0.4     Iris-setosa
# ..                 ...               ...  ...               ...             ...
# 144                6.7               3.0  ...               2.3  Iris-virginica
# 145                6.3               2.5  ...               1.9  Iris-virginica
# 146                6.5               3.0  ...               2.0  Iris-virginica
# 147                6.2               3.4  ...               2.3  Iris-virginica
# 148                5.9               3.0  ...               1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
iris.describe()
# Out:
#        Sepal length (cm)  Sepal width (cm)  Petal length (cm)  Petal width (cm)
# count         149.000000        149.000000         149.000000        149.000000
# mean            5.848322          3.051007           3.774497          1.205369
# std             0.828594          0.433499           1.759651          0.761292
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.400000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %%
iris.groupby('Iris_species').size()
# Out:
# Iris_species
# Iris-setosa        49
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
fig = plt.subplots(figsize=(8,8))
plt.scatter(iris['Sepal length (cm)'], iris['Petal length (cm)'])

plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')

plt.show()

# %%
colors = {'Iris-setosa':'r', 'Iris-virginica':'g', 'Iris-versicolor':'b'}

# create a figure and axis
fig, ax = plt.subplots(figsize=(8,8))
# plot each data-point
for i in range(len(iris_feat['Sepal length (cm)'])):
    ax.scatter(iris_feat['Sepal length (cm)'][i], iris_feat['Sepal width (cm)'][i], color=colors[iris_species[i]])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')

ax.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# get columns to plot
columns = iris_feat.columns
# create x data
x_data = range(0, iris.shape[0])
# create figure and axis
fig, ax = plt.subplots(figsize=(15,10))
# plot each column
for column in columns:
    ax.plot(x_data, iris[column], label=column)
# set title and legend
ax.set_title('Iris Dataset')
ax.legend()

# %%
corr = iris.corr()
fig, ax = plt.subplots(figsize=(15,10))
img = ax.imshow(corr.values,cmap = "magma_r")
# set labels
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)
cbar = ax.figure.colorbar(img, ax=ax ,cmap='')
plt.setp(ax.get_xticklabels(), rotation=30, ha="right",
         rotation_mode="anchor")
# text annotations.
for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        if corr.iloc[i, j]<0:
            text = ax.text(j, i, np.around(corr.iloc[i, j], decimals=2),
                       ha="center", va="center", color="black")
        else:
            text = ax.text(j, i, np.around(corr.iloc[i, j], decimals=2),
                       ha="center", va="center", color="white")

# %%
df = iris.groupby('Iris_species')['Sepal length (cm)'].sum().to_frame().reset_index()
#Creating the bar chart 
fig = plt.subplots(figsize=(10,6))
plt.bar(df['Iris_species'], df['Sepal length (cm)'], color = ['cornflowerblue','lightseagreen','steelblue']) 
#Adding the aesthetics
plt.title('Bar Chart')
plt.xlabel('Iris Species')
plt.ylabel('Sepal length') 
#Show the plot
plt.show()

# %%
train, test = train_test_split(iris, test_size = 0.4, stratify = iris['Iris_species'])

# %%
sns.pairplot(train, hue="Iris_species", height = 2, palette = 'colorblind');

# %%
iris
# Out:
#      Sepal length (cm)  Sepal width (cm)  ...  Petal width (cm)    Iris_species
# 0                  4.9               3.0  ...               0.2     Iris-setosa
# 1                  4.7               3.2  ...               0.2     Iris-setosa
# 2                  4.6               3.1  ...               0.2     Iris-setosa
# 3                  5.0               3.6  ...               0.2     Iris-setosa
# 4                  5.4               3.9  ...               0.4     Iris-setosa
# ..                 ...               ...  ...               ...             ...
# 144                6.7               3.0  ...               2.3  Iris-virginica
# 145                6.3               2.5  ...               1.9  Iris-virginica
# 146                6.5               3.0  ...               2.0  Iris-virginica
# 147                6.2               3.4  ...               2.3  Iris-virginica
# 148                5.9               3.0  ...               1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
X = iris

# %%
X = np.array(X)

# %%
X_train = X[0:50,0:2]
y_train = X[50:100,0:2]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Activation
from tensorflow.nn import sigmoid, tanh, softmax, relu, leaky_relu
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.losses import MSE, MAE

# %%
plt.figure(figsize=(8,8))
plt.scatter(X_train[:,0], X_train[:,1], c='r', label='Iris-setosa')
plt.scatter(y_train[:,0], y_train[:,1], c='b', label='Iris-versicolor')
plt.ylabel("Sepal length")
plt.xlabel("Sepal width")
plt.legend()
plt.grid()
plt.show()

# %%
X1 = X_train
X2 = y_train

# %%
X1 = np.append(X1,np.ones((X1.shape[0],1)),axis=1)
X2 = np.append(X2,np.zeros((X2.shape[0],1)),axis=1)

### Combine to a single dataset
X = np.vstack((X1,X2))
np.random.shuffle(X)
X_train = X[:,0:2]
y_train = X[:,-1]

# %%
X_train = X_train.astype(np.float)
y_train = y_train.astype(np.float)

# %% [markdown]
# # **Initializing the Models**

# %%
model1 = tf.keras.Sequential()
model1.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model1.add(tf.keras.layers.Dense(10, activation='relu'))
model1.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.01
model1.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 10)                30
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 47
# Trainable params: 47
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2 = tf.keras.Sequential()
model2.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model2.add(tf.keras.layers.Dense(11, activation='relu'))
model2.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.02
model2.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 2)                 6
#
#  dense_4 (Dense)             (None, 11)                33
#
#  dense_5 (Dense)             (None, 1)                 12
#
# =================================================================
# Total params: 51
# Trainable params: 51
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3 = tf.keras.Sequential()
model3.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model3.add(tf.keras.layers.Dense(12, activation='relu'))
model3.add(tf.keras.layers.Dense(30))
model3.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.03
model3.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 2)                 6
#
#  dense_7 (Dense)             (None, 12)                36
#
#  dense_8 (Dense)             (None, 30)                390
#
#  dense_9 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 463
# Trainable params: 463
# Non-trainable params: 0
# _________________________________________________________________

# %%
model4 = tf.keras.Sequential()
model4.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model4.add(tf.keras.layers.Dense(13, activation='relu'))
model4.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.04
model4.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 2)                 6
#
#  dense_11 (Dense)            (None, 13)                39
#
#  dense_12 (Dense)            (None, 1)                 14
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________

# %%
model5 = tf.keras.Sequential()
model5.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model5.add(tf.keras.layers.Dense(14, activation='relu'))
model5.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.05
model5.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 2)                 6
#
#  dense_14 (Dense)            (None, 14)                42
#
#  dense_15 (Dense)            (None, 1)                 15
#
# =================================================================
# Total params: 63
# Trainable params: 63
# Non-trainable params: 0
# _________________________________________________________________

# %%
model6 = tf.keras.Sequential()
model6.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model6.add(tf.keras.layers.Dense(15, activation='relu'))
model6.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.06
model6.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model6.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 2)                 6
#
#  dense_17 (Dense)            (None, 15)                45
#
#  dense_18 (Dense)            (None, 1)                 16
#
# =================================================================
# Total params: 67
# Trainable params: 67
# Non-trainable params: 0
# _________________________________________________________________

# %%
model7 = tf.keras.Sequential()
model7.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model7.add(tf.keras.layers.Dense(16, activation='relu'))
model7.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.07
model7.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model7.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 2)                 6
#
#  dense_20 (Dense)            (None, 16)                48
#
#  dense_21 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 71
# Trainable params: 71
# Non-trainable params: 0
# _________________________________________________________________

# %%
model8 = tf.keras.Sequential()
model8.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model8.add(tf.keras.layers.Dense(17, activation='relu'))
model8.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.08
model8.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model8.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 2)                 6
#
#  dense_23 (Dense)            (None, 17)                51
#
#  dense_24 (Dense)            (None, 1)                 18
#
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________

# %%
model9 = tf.keras.Sequential()
model9.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model9.add(tf.keras.layers.Dense(18, activation='relu'))
model9.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.09
model9.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model9.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 2)                 6
#
#  dense_26 (Dense)            (None, 18)                54
#
#  dense_27 (Dense)            (None, 1)                 19
#
# =================================================================
# Total params: 79
# Trainable params: 79
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Training the Models**

# %%
history1 = model1.fit(X_train, y_train, epochs=50, batch_size=1)
plt.figure(figsize=(14,7))
plt.title('Loss Curve')
plt.subplot(121)
plt.plot(history1.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.subplot(121)
plt.plot(history1.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 4ms/step - loss: 0.6449 - accuracy: 0.6200
# Epoch 2/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5218 - accuracy: 0.7900
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.4274 - accuracy: 0.8100
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3432 - accuracy: 0.8500
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2723 - accuracy: 0.9100
# Epoch 6/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2580 - accuracy: 0.9300
# Epoch 7/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2410 - accuracy: 0.9400
# Epoch 8/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2100 - accuracy: 0.9700
# Epoch 9/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1917 - accuracy: 0.9600
# Epoch 10/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1752 - accuracy: 0.9600
# Epoch 11/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1867 - accuracy: 0.9600
# Epoch 12/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1571 - accuracy: 0.9600
# Epoch 13/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1686 - accuracy: 0.9500
# Epoch 14/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1502 - accuracy: 0.9700
# Epoch 15/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1437 - accuracy: 0.9600
# Epoch 16/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1448 - accuracy: 0.9600
# Epoch 17/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1406 - accuracy: 0.9600
# Epoch 18/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1273 - accuracy: 0.9700
# Epoch 19/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1165 - accuracy: 0.9800
# Epoch 20/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1613 - accuracy: 0.9500
# Epoch 21/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1658 - accuracy: 0.9600
# Epoch 22/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1152 - accuracy: 0.9500
# Epoch 23/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1593 - accuracy: 0.9500
# Epoch 24/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1619 - accuracy: 0.9500
# Epoch 25/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 0.9500
# Epoch 26/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1268 - accuracy: 0.9700
# Epoch 27/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1187 - accuracy: 0.9800
# Epoch 28/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1247 - accuracy: 0.9600
# Epoch 29/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1230 - accuracy: 0.9500
# Epoch 30/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1461 - accuracy: 0.9700
# Epoch 31/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1078 - accuracy: 0.9800
# Epoch 32/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1085 - accuracy: 0.9800
# Epoch 33/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.9700
# Epoch 34/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.9800
# Epoch 35/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9700
# Epoch 36/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1134 - accuracy: 0.9800
# Epoch 37/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.9800
# Epoch 38/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1193 - accuracy: 0.9700
# Epoch 39/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1045 - accuracy: 0.9800
# Epoch 40/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1095 - accuracy: 0.9700
# Epoch 41/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0969 - accuracy: 0.9800
# Epoch 42/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0995 - accuracy: 0.9800
# Epoch 43/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0992 - accuracy: 0.9800
# Epoch 44/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1311 - accuracy: 0.9500
# Epoch 45/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1300 - accuracy: 0.9700
# Epoch 46/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1199 - accuracy: 0.9600
# Epoch 47/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1044 - accuracy: 0.9700
# Epoch 48/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1236 - accuracy: 0.9600
# Epoch 49/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1153 - accuracy: 0.9700
# Epoch 50/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1065 - accuracy: 0.9800
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
history2 = model2.fit(X_train, y_train, epochs=50, batch_size=1)
plt.figure(figsize=(14,7))
plt.title('Loss Curve')
plt.subplot(121)
plt.plot(history2.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.subplot(121)
plt.plot(history2.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7398 - accuracy: 0.5000
# Epoch 2/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6946 - accuracy: 0.5200
# Epoch 3/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6796 - accuracy: 0.6400
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6420 - accuracy: 0.7400
# Epoch 5/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5904 - accuracy: 0.8100
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4966 - accuracy: 0.8900
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4408 - accuracy: 0.8600
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3759 - accuracy: 0.9200
# Epoch 9/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3292 - accuracy: 0.9000
# Epoch 10/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2359 - accuracy: 0.9600
# Epoch 11/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2637 - accuracy: 0.9200
# Epoch 12/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2595 - accuracy: 0.9000
# Epoch 13/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3453 - accuracy: 0.8700
# Epoch 14/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2358 - accuracy: 0.9100
# Epoch 15/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2387 - accuracy: 0.9400
# Epoch 16/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2682 - accuracy: 0.8900
# Epoch 17/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2327 - accuracy: 0.9400
# Epoch 18/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2299 - accuracy: 0.9300
# Epoch 19/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2126 - accuracy: 0.9300
# Epoch 20/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1417 - accuracy: 0.9700
# Epoch 21/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1651 - accuracy: 0.9500
# Epoch 22/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 0.9400
# Epoch 23/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1949 - accuracy: 0.9400
# Epoch 24/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1197 - accuracy: 0.9800
# Epoch 25/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1469 - accuracy: 0.9500
# Epoch 26/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1298 - accuracy: 0.9600
# Epoch 27/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1672 - accuracy: 0.9500
# Epoch 28/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1115 - accuracy: 0.9800
# Epoch 29/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1800 - accuracy: 0.9400
# Epoch 30/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1106 - accuracy: 0.9800
# Epoch 31/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1984 - accuracy: 0.9300
# Epoch 32/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1120 - accuracy: 0.9800
# Epoch 33/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1910 - accuracy: 0.9500
# Epoch 34/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1824 - accuracy: 0.9500
# Epoch 35/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1266 - accuracy: 0.9500
# Epoch 36/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1685 - accuracy: 0.9200
# Epoch 37/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1113 - accuracy: 0.9700
# Epoch 38/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1481 - accuracy: 0.9400
# Epoch 39/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1184 - accuracy: 0.9600
# Epoch 40/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0949 - accuracy: 0.9800
# Epoch 41/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0942 - accuracy: 0.9800
# Epoch 42/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1389 - accuracy: 0.9500
# Epoch 43/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1747 - accuracy: 0.9400
# Epoch 44/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1446 - accuracy: 0.9500
# Epoch 45/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0987 - accuracy: 0.9700
# Epoch 46/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2788 - accuracy: 0.9200
# Epoch 47/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1067 - accuracy: 0.9700
# Epoch 48/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1178 - accuracy: 0.9600
# Epoch 49/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1067 - accuracy: 0.9700
# Epoch 50/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1062 - accuracy: 0.9800
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
history3 = model3.fit(X_train, y_train, epochs=50, batch_size=1)
plt.figure(figsize=(14,7))
plt.title('Loss Curve')
plt.subplot(121)
plt.plot(history3.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.subplot(121)
plt.plot(history3.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 1ms/step - loss: 0.7009 - accuracy: 0.3900
# Epoch 2/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7015 - accuracy: 0.4400
# Epoch 3/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7010 - accuracy: 0.4300
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7009 - accuracy: 0.4300
# Epoch 5/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7010 - accuracy: 0.3700
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6982 - accuracy: 0.5200
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6992 - accuracy: 0.5200
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7013 - accuracy: 0.4400
# Epoch 9/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7004 - accuracy: 0.4300
# Epoch 10/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6978 - accuracy: 0.5400
# Epoch 11/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6973 - accuracy: 0.5000
# Epoch 12/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7008 - accuracy: 0.4900
# Epoch 13/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7003 - accuracy: 0.4900
# Epoch 14/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7004 - accuracy: 0.3800
# Epoch 15/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6903 - accuracy: 0.5600
# Epoch 16/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7021 - accuracy: 0.4900
# Epoch 17/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.4600
# Epoch 18/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7001 - accuracy: 0.3600
# Epoch 19/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6989 - accuracy: 0.4900
# Epoch 20/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6999 - accuracy: 0.4600
# Epoch 21/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6996 - accuracy: 0.4500
# Epoch 22/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6997 - accuracy: 0.4200
# Epoch 23/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6971 - accuracy: 0.5000
# Epoch 24/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6999 - accuracy: 0.4300
# Epoch 25/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6989 - accuracy: 0.4400
# Epoch 26/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6992 - accuracy: 0.3800
# Epoch 27/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6989 - accuracy: 0.4600
# Epoch 28/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6980 - accuracy: 0.4600
# Epoch 29/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6978 - accuracy: 0.4700
# Epoch 30/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6995 - accuracy: 0.4400
# Epoch 31/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6992 - accuracy: 0.4000
# Epoch 32/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6984 - accuracy: 0.4700
# Epoch 33/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6987 - accuracy: 0.4300
# Epoch 34/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6979 - accuracy: 0.4800
# Epoch 35/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.4300
# Epoch 36/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6987 - accuracy: 0.4400
# Epoch 37/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6988 - accuracy: 0.4500
# Epoch 38/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6976 - accuracy: 0.4900
# Epoch 39/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6978 - accuracy: 0.4600
# Epoch 40/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6985 - accuracy: 0.4200
# Epoch 41/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6988 - accuracy: 0.3900
# Epoch 42/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6950 - accuracy: 0.5300
# Epoch 43/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6990 - accuracy: 0.4900
# Epoch 44/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6982 - accuracy: 0.4500
# Epoch 45/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6967 - accuracy: 0.4700
# Epoch 46/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6974 - accuracy: 0.4500
# Epoch 47/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6959 - accuracy: 0.5200
# Epoch 48/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6988 - accuracy: 0.4500
# Epoch 49/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6973 - accuracy: 0.5100
# Epoch 50/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6975 - accuracy: 0.5100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
history4 = model4.fit(X_train, y_train, epochs=50, batch_size=1)
plt.figure(figsize=(14,7))
plt.title('Loss Curve')
plt.subplot(121)
plt.plot(history4.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.subplot(121)
plt.plot(history4.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7697 - accuracy: 0.4700
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6295 - accuracy: 0.6800
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.7700
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6560 - accuracy: 0.5900
# Epoch 5/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7078 - accuracy: 0.5000
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6965 - accuracy: 0.5000
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6982 - accuracy: 0.4200
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6976 - accuracy: 0.4200
# Epoch 9/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6973 - accuracy: 0.4500
# Epoch 10/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6976 - accuracy: 0.5000
# Epoch 11/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6974 - accuracy: 0.4800
# Epoch 12/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6981 - accuracy: 0.4400
# Epoch 13/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6980 - accuracy: 0.3800
# Epoch 14/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6979 - accuracy: 0.4500
# Epoch 15/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6947 - accuracy: 0.5000
# Epoch 16/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6982 - accuracy: 0.4200
# Epoch 17/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6972 - accuracy: 0.4900
# Epoch 18/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6978 - accuracy: 0.4500
# Epoch 19/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6981 - accuracy: 0.4400
# Epoch 20/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6976 - accuracy: 0.4800
# Epoch 21/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6973 - accuracy: 0.4700
# Epoch 22/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6975 - accuracy: 0.4900
# Epoch 23/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6978 - accuracy: 0.4400
# Epoch 24/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6973 - accuracy: 0.4600
# Epoch 25/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6978 - accuracy: 0.4400
# Epoch 26/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6981 - accuracy: 0.4300
# Epoch 27/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6981 - accuracy: 0.3800
# Epoch 28/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6973 - accuracy: 0.4500
# Epoch 29/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6964 - accuracy: 0.5100
# Epoch 30/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6981 - accuracy: 0.4600
# Epoch 31/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6962 - accuracy: 0.5300
# Epoch 32/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6978 - accuracy: 0.4800
# Epoch 33/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6981 - accuracy: 0.4700
# Epoch 34/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6979 - accuracy: 0.4600
# Epoch 35/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6975 - accuracy: 0.4300
# Epoch 36/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6975 - accuracy: 0.5000
# Epoch 37/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6964 - accuracy: 0.4900
# Epoch 38/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6983 - accuracy: 0.4800
# Epoch 39/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6980 - accuracy: 0.4700
# Epoch 40/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6980 - accuracy: 0.4400
# Epoch 41/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6975 - accuracy: 0.4000
# Epoch 42/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6965 - accuracy: 0.4800
# Epoch 43/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6975 - accuracy: 0.4800
# Epoch 44/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6969 - accuracy: 0.4900
# Epoch 45/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6971 - accuracy: 0.4700
# Epoch 46/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6983 - accuracy: 0.4600
# Epoch 47/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6957 - accuracy: 0.5100
# Epoch 48/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6977 - accuracy: 0.4400
# Epoch 49/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6975 - accuracy: 0.4400
# Epoch 50/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6982 - accuracy: 0.3900
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
history5 = model5.fit(X_train, y_train, epochs=50, batch_size=1)
plt.figure(figsize=(14,7))
plt.title('Loss Curve')
plt.subplot(121)
plt.plot(history5.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.subplot(121)
plt.plot(history5.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6724 - accuracy: 0.6700
# Epoch 2/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5081 - accuracy: 0.7600
# Epoch 3/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5314 - accuracy: 0.7300
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4773 - accuracy: 0.7900
# Epoch 5/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4077 - accuracy: 0.8500
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3803 - accuracy: 0.8500
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4819 - accuracy: 0.7700
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3840 - accuracy: 0.8500
# Epoch 9/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3614 - accuracy: 0.8600
# Epoch 10/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1693 - accuracy: 0.9500
# Epoch 11/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4668 - accuracy: 0.8000
# Epoch 12/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2307 - accuracy: 0.9200
# Epoch 13/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4068 - accuracy: 0.8300
# Epoch 14/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2256 - accuracy: 0.9300
# Epoch 15/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1408 - accuracy: 0.9700
# Epoch 16/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3067 - accuracy: 0.9000
# Epoch 17/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3424 - accuracy: 0.8700
# Epoch 18/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2408 - accuracy: 0.9100
# Epoch 19/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1369 - accuracy: 0.9600
# Epoch 20/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2455 - accuracy: 0.9200
# Epoch 21/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 0.9600
# Epoch 22/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2058 - accuracy: 0.9600
# Epoch 23/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1036 - accuracy: 0.9700
# Epoch 24/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1491 - accuracy: 0.9600
# Epoch 25/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1689 - accuracy: 0.9500
# Epoch 26/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1395 - accuracy: 0.9500
# Epoch 27/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1029 - accuracy: 0.9800
# Epoch 28/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1629 - accuracy: 0.9500
# Epoch 29/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1976 - accuracy: 0.9500
# Epoch 30/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0979 - accuracy: 0.9800
# Epoch 31/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0941 - accuracy: 0.9800
# Epoch 32/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2241 - accuracy: 0.9300
# Epoch 33/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1428 - accuracy: 0.9500
# Epoch 34/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1671 - accuracy: 0.9400
# Epoch 35/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1589 - accuracy: 0.9400
# Epoch 36/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1072 - accuracy: 0.9700
# Epoch 37/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1268 - accuracy: 0.9700
# Epoch 38/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0923 - accuracy: 0.9800
# Epoch 39/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0946 - accuracy: 0.9800
# Epoch 40/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0885 - accuracy: 0.9800
# Epoch 41/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1945 - accuracy: 0.9400
# Epoch 42/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1619 - accuracy: 0.9600
# Epoch 43/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0931 - accuracy: 0.9800
# Epoch 44/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0962 - accuracy: 0.9800
# Epoch 45/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0916 - accuracy: 0.9800
# Epoch 46/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1552 - accuracy: 0.9600
# Epoch 47/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0998 - accuracy: 0.9700
# Epoch 48/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1780 - accuracy: 0.9400
# Epoch 49/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1679 - accuracy: 0.9500
# Epoch 50/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1164 - accuracy: 0.9700
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
history6 = model6.fit(X_train, y_train, epochs=50, batch_size=1)
plt.figure(figsize=(14,7))
plt.title('Loss Curve')
plt.subplot(121)
plt.plot(history6.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.subplot(121)
plt.plot(history6.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7614 - accuracy: 0.4000
# Epoch 2/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7031 - accuracy: 0.4900
# Epoch 3/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6989 - accuracy: 0.4800
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6971 - accuracy: 0.4900
# Epoch 5/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7004 - accuracy: 0.4500
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6997 - accuracy: 0.4600
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7000 - accuracy: 0.4400
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6977 - accuracy: 0.4900
# Epoch 9/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7011 - accuracy: 0.4600
# Epoch 10/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7003 - accuracy: 0.4100
# Epoch 11/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6978 - accuracy: 0.4700
# Epoch 12/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7001 - accuracy: 0.4500
# Epoch 13/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7003 - accuracy: 0.4600
# Epoch 14/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6954 - accuracy: 0.5000
# Epoch 15/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6999 - accuracy: 0.4600
# Epoch 16/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6940 - accuracy: 0.5200
# Epoch 17/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7001 - accuracy: 0.4700
# Epoch 18/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6992 - accuracy: 0.4700
# Epoch 19/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6986 - accuracy: 0.4700
# Epoch 20/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7008 - accuracy: 0.4100
# Epoch 21/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6983 - accuracy: 0.4600
# Epoch 22/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6996 - accuracy: 0.4400
# Epoch 23/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6973 - accuracy: 0.5200
# Epoch 24/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7000 - accuracy: 0.4600
# Epoch 25/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.5000
# Epoch 26/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6994 - accuracy: 0.4700
# Epoch 27/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6981 - accuracy: 0.5000
# Epoch 28/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6990 - accuracy: 0.4100
# Epoch 29/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7007 - accuracy: 0.4300
# Epoch 30/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6984 - accuracy: 0.5000
# Epoch 31/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7004 - accuracy: 0.3700
# Epoch 32/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6999 - accuracy: 0.4600
# Epoch 33/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6998 - accuracy: 0.4800
# Epoch 34/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6992 - accuracy: 0.4700
# Epoch 35/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6998 - accuracy: 0.4200
# Epoch 36/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7002 - accuracy: 0.4100
# Epoch 37/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6966 - accuracy: 0.5400
# Epoch 38/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6999 - accuracy: 0.4900
# Epoch 39/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6974 - accuracy: 0.4900
# Epoch 40/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7007 - accuracy: 0.4200
# Epoch 41/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6998 - accuracy: 0.4400
# Epoch 42/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6999 - accuracy: 0.4200
# Epoch 43/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.4500
# Epoch 44/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6990 - accuracy: 0.5100
# Epoch 45/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7000 - accuracy: 0.4400
# Epoch 46/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7002 - accuracy: 0.4200
# Epoch 47/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6987 - accuracy: 0.4600
# Epoch 48/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6987 - accuracy: 0.4600
# Epoch 49/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6952 - accuracy: 0.5500
# Epoch 50/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7011 - accuracy: 0.3900
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
history7 = model7.fit(X_train, y_train, epochs=50, batch_size=1)
plt.figure(figsize=(14,7))
plt.title('Loss Curve')
plt.subplot(121)
plt.plot(history7.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.subplot(121)
plt.plot(history7.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7154 - accuracy: 0.6000
# Epoch 2/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5919 - accuracy: 0.7000
# Epoch 3/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4843 - accuracy: 0.7500
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3442 - accuracy: 0.8300
# Epoch 5/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8500
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3034 - accuracy: 0.8900
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1940 - accuracy: 0.9600
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2772 - accuracy: 0.9100
# Epoch 9/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2551 - accuracy: 0.8800
# Epoch 10/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1936 - accuracy: 0.9200
# Epoch 11/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2062 - accuracy: 0.9600
# Epoch 12/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1455 - accuracy: 0.9700
# Epoch 13/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3168 - accuracy: 0.9200
# Epoch 14/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2093 - accuracy: 0.9300
# Epoch 15/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2928 - accuracy: 0.8800
# Epoch 16/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1380 - accuracy: 0.9700
# Epoch 17/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1804 - accuracy: 0.9500
# Epoch 18/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2821 - accuracy: 0.8700
# Epoch 19/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1384 - accuracy: 0.9500
# Epoch 20/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1859 - accuracy: 0.9700
# Epoch 21/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2067 - accuracy: 0.9700
# Epoch 22/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3808 - accuracy: 0.8300
# Epoch 23/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2586 - accuracy: 0.8800
# Epoch 24/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2968 - accuracy: 0.9100
# Epoch 25/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2675 - accuracy: 0.9100
# Epoch 26/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1391 - accuracy: 0.9600
# Epoch 27/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2896 - accuracy: 0.9100
# Epoch 28/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2071 - accuracy: 0.9500
# Epoch 29/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1485 - accuracy: 0.9700
# Epoch 30/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2643 - accuracy: 0.9300
# Epoch 31/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2147 - accuracy: 0.9400
# Epoch 32/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1541 - accuracy: 0.9600
# Epoch 33/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2375 - accuracy: 0.9300
# Epoch 34/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1383 - accuracy: 0.9600
# Epoch 35/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2655 - accuracy: 0.9200
# Epoch 36/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1430 - accuracy: 0.9800
# Epoch 37/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1875 - accuracy: 0.9400
# Epoch 38/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2201 - accuracy: 0.9500
# Epoch 39/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1857 - accuracy: 0.9500
# Epoch 40/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1614 - accuracy: 0.9700
# Epoch 41/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1312 - accuracy: 0.9800
# Epoch 42/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1450 - accuracy: 0.9600
# Epoch 43/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 0.9600
# Epoch 44/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1811 - accuracy: 0.9300
# Epoch 45/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1327 - accuracy: 0.9800
# Epoch 46/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1381 - accuracy: 0.9800
# Epoch 47/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1740 - accuracy: 0.9400
# Epoch 48/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1836 - accuracy: 0.9700
# Epoch 49/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3124 - accuracy: 0.8800
# Epoch 50/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2180 - accuracy: 0.9200
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
history8 = model8.fit(X_train, y_train, epochs=50, batch_size=1)
plt.figure(figsize=(14,7))
plt.title('Loss Curve')
plt.subplot(121)
plt.plot(history8.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.subplot(121)
plt.plot(history8.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5196 - accuracy: 0.7700
# Epoch 2/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4242 - accuracy: 0.8300
# Epoch 3/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5353 - accuracy: 0.7400
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6124 - accuracy: 0.6400
# Epoch 5/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7001 - accuracy: 0.5300
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7051 - accuracy: 0.4700
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7030 - accuracy: 0.3400
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7010 - accuracy: 0.4500
# Epoch 9/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7026 - accuracy: 0.4500
# Epoch 10/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6980 - accuracy: 0.5500
# Epoch 11/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7017 - accuracy: 0.4600
# Epoch 12/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7014 - accuracy: 0.4700
# Epoch 13/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7020 - accuracy: 0.4800
# Epoch 14/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7012 - accuracy: 0.5000
# Epoch 15/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7028 - accuracy: 0.4100
# Epoch 16/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7021 - accuracy: 0.4400
# Epoch 17/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7027 - accuracy: 0.4600
# Epoch 18/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7007 - accuracy: 0.4600
# Epoch 19/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6963 - accuracy: 0.5400
# Epoch 20/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6934 - accuracy: 0.5500
# Epoch 21/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7041 - accuracy: 0.4400
# Epoch 22/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7011 - accuracy: 0.4900
# Epoch 23/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7009 - accuracy: 0.5100
# Epoch 24/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6918 - accuracy: 0.5600
# Epoch 25/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6992 - accuracy: 0.5100
# Epoch 26/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7013 - accuracy: 0.4800
# Epoch 27/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7008 - accuracy: 0.4100
# Epoch 28/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7013 - accuracy: 0.5100
# Epoch 29/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7010 - accuracy: 0.5000
# Epoch 30/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7027 - accuracy: 0.4200
# Epoch 31/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7016 - accuracy: 0.4200
# Epoch 32/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6969 - accuracy: 0.4600
# Epoch 33/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6959 - accuracy: 0.5500
# Epoch 34/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7029 - accuracy: 0.4900
# Epoch 35/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6992 - accuracy: 0.5200
# Epoch 36/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7028 - accuracy: 0.4300
# Epoch 37/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7025 - accuracy: 0.4200
# Epoch 38/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7014 - accuracy: 0.4500
# Epoch 39/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7010 - accuracy: 0.5100
# Epoch 40/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7015 - accuracy: 0.4200
# Epoch 41/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.5100
# Epoch 42/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7019 - accuracy: 0.4300
# Epoch 43/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7030 - accuracy: 0.4200
# Epoch 44/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7016 - accuracy: 0.4300
# Epoch 45/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7028 - accuracy: 0.3900
# Epoch 46/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7035 - accuracy: 0.4000
# Epoch 47/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7022 - accuracy: 0.4700
# Epoch 48/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7019 - accuracy: 0.4600
# Epoch 49/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7002 - accuracy: 0.4600
# Epoch 50/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7003 - accuracy: 0.4900
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
history9 = model9.fit(X_train, y_train, epochs=50, batch_size=1)
plt.figure(figsize=(14,7))
plt.title('Loss Curve')
plt.subplot(121)
plt.plot(history9.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.subplot(121)
plt.plot(history9.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6674 - accuracy: 0.6600
# Epoch 2/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6119 - accuracy: 0.6900
# Epoch 3/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4572 - accuracy: 0.7700
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7431 - accuracy: 0.4700
# Epoch 5/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7033 - accuracy: 0.4500
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7031 - accuracy: 0.4800
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7012 - accuracy: 0.4900
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7038 - accuracy: 0.4300
# Epoch 9/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7036 - accuracy: 0.4200
# Epoch 10/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6985 - accuracy: 0.4800
# Epoch 11/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7031 - accuracy: 0.4600
# Epoch 12/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7041 - accuracy: 0.4800
# Epoch 13/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7003 - accuracy: 0.5000
# Epoch 14/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7024 - accuracy: 0.4900
# Epoch 15/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7035 - accuracy: 0.4100
# Epoch 16/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7021 - accuracy: 0.4300
# Epoch 17/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6942 - accuracy: 0.5500
# Epoch 18/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7072 - accuracy: 0.4900
# Epoch 19/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7027 - accuracy: 0.4200
# Epoch 20/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7028 - accuracy: 0.4800
# Epoch 21/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7037 - accuracy: 0.4200
# Epoch 22/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7041 - accuracy: 0.3800
# Epoch 23/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6980 - accuracy: 0.5300
# Epoch 24/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7043 - accuracy: 0.4600
# Epoch 25/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7016 - accuracy: 0.4900
# Epoch 26/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7037 - accuracy: 0.4300
# Epoch 27/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6991 - accuracy: 0.5000
# Epoch 28/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7004 - accuracy: 0.5100
# Epoch 29/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7049 - accuracy: 0.4800
# Epoch 30/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7006 - accuracy: 0.5200
# Epoch 31/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6979 - accuracy: 0.5200
# Epoch 32/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7037 - accuracy: 0.4600
# Epoch 33/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7032 - accuracy: 0.4600
# Epoch 34/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7025 - accuracy: 0.4800
# Epoch 35/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7030 - accuracy: 0.4300
# Epoch 36/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7029 - accuracy: 0.4700
# Epoch 37/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6990 - accuracy: 0.4900
# Epoch 38/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7034 - accuracy: 0.4400
# Epoch 39/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6950 - accuracy: 0.5700
# Epoch 40/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7016 - accuracy: 0.4600
# Epoch 41/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7015 - accuracy: 0.5100
# Epoch 42/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7013 - accuracy: 0.4900
# Epoch 43/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7030 - accuracy: 0.4900
# Epoch 44/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7034 - accuracy: 0.4800
# Epoch 45/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7024 - accuracy: 0.5000
# Epoch 46/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7040 - accuracy: 0.4300
# Epoch 47/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7038 - accuracy: 0.4200
# Epoch 48/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7010 - accuracy: 0.5000
# Epoch 49/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7042 - accuracy: 0.4100
# Epoch 50/50
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7038 - accuracy: 0.3700
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# # **Graphs of the Result**

# %%
def plot_boundary(clf, X, Y):
    h = 0.02
    x_min, x_max = X[:,0].min() - 10*h, X[:,0].max() + 10*h
    y_min, y_max = X[:,1].min() - 10*h, X[:,1].max() + 10*h
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(5,5))
    plt.contourf(xx, yy, Z, alpha=0.25)
    plt.contour(xx, yy, Z, colors='k', linewidths=0.7)
    plt.scatter(X[:,0], X[:,1], c=Y, edgecolors='k');

# %%
plot_boundary(model1, X_train, y_train)

# %%
plot_boundary(model2, X_train, y_train)

# %%
plot_boundary(model3, X_train, y_train)

# %%
plot_boundary(model4, X_train, y_train)

# %%
plot_boundary(model5, X_train, y_train)

# %%
plot_boundary(model6, X_train, y_train)

# %%
plot_boundary(model7, X_train, y_train)

# %%
plot_boundary(model8, X_train, y_train)

# %%
plot_boundary(model9, X_train, y_train)
