# %% [markdown]
# <a href="https://colab.research.google.com/github/Gonzales-James/DL/blob/main/Lab01-Machine_Learning_Review/58026_Lab01_Henerawr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
iris = pd.read_csv('/content/iris.data') # iris dataset
iris.columns = ['Sepal length (cm)', 'Sepal width (cm)', 'Petal length (cm)', 'Petal width (cm)', 'Iris_species']
iris_feat = iris.iloc[:,:-1]
iris_species = iris.iloc[:,-1]

# %%
iris
# Out:
#      Sepal length (cm)  Sepal width (cm)  ...  Petal width (cm)    Iris_species
# 0                  4.9               3.0  ...               0.2     Iris-setosa
# 1                  4.7               3.2  ...               0.2     Iris-setosa
# 2                  4.6               3.1  ...               0.2     Iris-setosa
# 3                  5.0               3.6  ...               0.2     Iris-setosa
# 4                  5.4               3.9  ...               0.4     Iris-setosa
# ..                 ...               ...  ...               ...             ...
# 144                6.7               3.0  ...               2.3  Iris-virginica
# 145                6.3               2.5  ...               1.9  Iris-virginica
# 146                6.5               3.0  ...               2.0  Iris-virginica
# 147                6.2               3.4  ...               2.3  Iris-virginica
# 148                5.9               3.0  ...               1.8  Iris-virginica
#
# ...

# %%
iris.describe()
# Out:
#        Sepal length (cm)  Sepal width (cm)  Petal length (cm)  Petal width (cm)
# count         149.000000        149.000000         149.000000        149.000000
# mean            5.848322          3.051007           3.774497          1.205369
# std             0.828594          0.433499           1.759651          0.761292
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.400000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %%
iris.groupby('Iris_species').size()
# Out:
# Iris_species
# Iris-setosa        49
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
fig = plt.subplots(figsize=(8,8))
plt.scatter(iris['Sepal length (cm)'], iris['Petal length (cm)'])

plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')

plt.show()

# %%
colors = {'Iris-setosa':'r', 'Iris-virginica':'g', 'Iris-versicolor':'b'}

# create a figure and axis
fig, ax = plt.subplots(figsize=(8,8))
# plot each data-point
for i in range(len(iris_feat['Sepal length (cm)'])):
    ax.scatter(iris_feat['Sepal length (cm)'][i], iris_feat['Sepal width (cm)'][i], color=colors[iris_species[i]])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')

ax.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# get columns to plot
columns = iris_feat.columns
# create x data
x_data = range(0, iris.shape[0])
# create figure and axis
fig, ax = plt.subplots(figsize=(15,10))
# plot each column
for column in columns:
    ax.plot(x_data, iris[column], label=column)
# set title and legend
ax.set_title('Iris Dataset')
ax.legend()

# %%
corr = iris.corr()
fig, ax = plt.subplots(figsize=(15,10))
img = ax.imshow(corr.values,cmap = "magma_r")
# set labels
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)
cbar = ax.figure.colorbar(img, ax=ax ,cmap='')
plt.setp(ax.get_xticklabels(), rotation=30, ha="right",
         rotation_mode="anchor")
# text annotations.
for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        if corr.iloc[i, j]<0:
            text = ax.text(j, i, np.around(corr.iloc[i, j], decimals=2),
                       ha="center", va="center", color="black")
        else:
            text = ax.text(j, i, np.around(corr.iloc[i, j], decimals=2),
                       ha="center", va="center", color="white")

# %%
df = iris.groupby('Iris_species')['Sepal length (cm)'].sum().to_frame().reset_index()
#Creating the bar chart 
fig = plt.subplots(figsize=(10,6))
plt.bar(df['Iris_species'], df['Sepal length (cm)'], color = ['cornflowerblue','lightseagreen','steelblue']) 
#Adding the aesthetics
plt.title('Bar Chart')
plt.xlabel('Iris Species')
plt.ylabel('Sepal length') 
#Show the plot
plt.show()

# %%
train, test = train_test_split(iris, test_size = 0.4, stratify = iris['Iris_species'])

# %%
sns.pairplot(train, hue="Iris_species", height = 2, palette = 'colorblind');

# %%
iris
# Out:
#      Sepal length (cm)  Sepal width (cm)  ...  Petal width (cm)    Iris_species
# 0                  4.9               3.0  ...               0.2     Iris-setosa
# 1                  4.7               3.2  ...               0.2     Iris-setosa
# 2                  4.6               3.1  ...               0.2     Iris-setosa
# 3                  5.0               3.6  ...               0.2     Iris-setosa
# 4                  5.4               3.9  ...               0.4     Iris-setosa
# ..                 ...               ...  ...               ...             ...
# 144                6.7               3.0  ...               2.3  Iris-virginica
# 145                6.3               2.5  ...               1.9  Iris-virginica
# 146                6.5               3.0  ...               2.0  Iris-virginica
# 147                6.2               3.4  ...               2.3  Iris-virginica
# 148                5.9               3.0  ...               1.8  Iris-virginica
#
# ...

# %%
X = iris

# %%
X = np.array(X)

# %%
X_train = X[0:50,0:2]
y_train = X[50:100,0:2]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Activation
from tensorflow.nn import sigmoid, tanh, softmax, relu, leaky_relu
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.losses import MSE, MAE

# %%
plt.figure(figsize=(8,8))
plt.scatter(X_train[:,0], X_train[:,1], c='r', label='Iris-setosa')
plt.scatter(y_train[:,0], y_train[:,1], c='b', label='Iris-versicolor')
plt.ylabel("Sepal length")
plt.xlabel("Sepal width")
plt.legend()
plt.grid()
plt.show()

# %%
X1 = X_train
X2 = y_train

# %%
X1 = np.append(X1,np.ones((X1.shape[0],1)),axis=1)
X2 = np.append(X2,np.zeros((X2.shape[0],1)),axis=1)

### Combine to a single dataset
X = np.vstack((X1,X2))
np.random.shuffle(X)
X_train = X[:,0:2]
y_train = X[:,-1]

# %%
X_train = X_train.astype(np.float)
y_train = y_train.astype(np.float)

# %% [markdown]
# # **Initializing the Models**

# %%
model1 = tf.keras.Sequential()
model1.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model1.add(tf.keras.layers.Dense(10, activation='relu'))
model1.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.01
model1.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 10)                30
#
#  dense_2 (Dense)             (None, 1)                 11
#
# ...
# Total params: 47
# Trainable params: 47
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2 = tf.keras.Sequential()
model2.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model2.add(tf.keras.layers.Dense(11, activation='relu'))
model2.add(tf.keras.layers.Dense(11, activation='tanh'))
model2.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.02
model2.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 2)                 6
#
#  dense_4 (Dense)             (None, 11)                33
#
#  dense_5 (Dense)             (None, 11)                132
#
#  dense_6 (Dense)             (None, 1)                 12
#
# ...
# Total params: 183
# Trainable params: 183
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3 = tf.keras.Sequential()
model3.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model3.add(tf.keras.layers.Dense(12, activation='relu'))
model3.add(tf.keras.layers.Dense(12))
model3.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.03
model3.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 2)                 6
#
#  dense_8 (Dense)             (None, 12)                36
#
#  dense_9 (Dense)             (None, 12)                156
#
#  dense_10 (Dense)            (None, 1)                 13
#
# ...
# Total params: 211
# Trainable params: 211
# Non-trainable params: 0
# _________________________________________________________________

# %%
model4 = tf.keras.Sequential()
model4.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model4.add(tf.keras.layers.Dense(13, activation='relu'))
model4.add(tf.keras.layers.Dense(11, activation='tanh'))
model4.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.04
model4.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_11 (Dense)            (None, 2)                 6
#
#  dense_12 (Dense)            (None, 13)                39
#
#  dense_13 (Dense)            (None, 11)                154
#
#  dense_14 (Dense)            (None, 1)                 12
#
# ...
# Total params: 211
# Trainable params: 211
# Non-trainable params: 0
# _________________________________________________________________

# %%
model5 = tf.keras.Sequential()
model5.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model5.add(tf.keras.layers.Dense(14, activation='relu'))
model5.add(tf.keras.layers.Dense(14, activation='tanh'))
model5.add(tf.keras.layers.Dense(14, activation='relu'))
model5.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.05
model5.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 2)                 6
#
#  dense_16 (Dense)            (None, 14)                42
#
#  dense_17 (Dense)            (None, 14)                210
#
#  dense_18 (Dense)            (None, 14)                210
#
#  dense_19 (Dense)            (None, 1)                 15
#
# ...
# Total params: 483
# Trainable params: 483
# Non-trainable params: 0
# _________________________________________________________________

# %%
model6 = tf.keras.Sequential()
model6.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model6.add(tf.keras.layers.Dense(15, activation='relu'))
model6.add(tf.keras.layers.Dense(15, activation='tanh'))
model6.add(tf.keras.layers.Dense(15, activation='sigmoid'))
model6.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.06
model6.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model6.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_20 (Dense)            (None, 2)                 6
#
#  dense_21 (Dense)            (None, 15)                45
#
#  dense_22 (Dense)            (None, 15)                240
#
#  dense_23 (Dense)            (None, 15)                240
#
#  dense_24 (Dense)            (None, 1)                 16
#
# ...
# Total params: 547
# Trainable params: 547
# Non-trainable params: 0
# _________________________________________________________________

# %%
model7 = tf.keras.Sequential()
model7.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model7.add(tf.keras.layers.Dense(16, activation='relu'))
model7.add(tf.keras.layers.Dense(16, activation='relu'))
model7.add(tf.keras.layers.Dense(16, activation='tanh'))
model7.add(tf.keras.layers.Dense(16, activation='tanh'))
model7.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.07
model7.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model7.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_25 (Dense)            (None, 2)                 6
#
#  dense_26 (Dense)            (None, 16)                48
#
#  dense_27 (Dense)            (None, 16)                272
#
#  dense_28 (Dense)            (None, 16)                272
#
#  dense_29 (Dense)            (None, 16)                272
#
#  dense_30 (Dense)            (None, 1)                 17
#
# ...
# Total params: 887
# Trainable params: 887
# Non-trainable params: 0
# _________________________________________________________________

# %%
model8 = tf.keras.Sequential()
model8.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model8.add(tf.keras.layers.Dense(17, activation='relu'))
model8.add(tf.keras.layers.Dense(17, activation='sigmoid'))
model8.add(tf.keras.layers.Dense(17, activation='relu'))
model8.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.08
model8.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model8.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_31 (Dense)            (None, 2)                 6
#
#  dense_32 (Dense)            (None, 17)                51
#
#  dense_33 (Dense)            (None, 17)                306
#
#  dense_34 (Dense)            (None, 17)                306
#
#  dense_35 (Dense)            (None, 1)                 18
#
# ...
# Total params: 687
# Trainable params: 687
# Non-trainable params: 0
# _________________________________________________________________

# %%
model9 = tf.keras.Sequential()
model9.add(tf.keras.layers.Dense(2, input_dim=2, activation='relu'))
model9.add(tf.keras.layers.Dense(18, activation='relu'))
model9.add(tf.keras.layers.Dense(18, activation='softmax'))
model9.add(tf.keras.layers.Dense(18, activation='tanh'))
model9.add(tf.keras.layers.Dense(18))
model9.add(tf.keras.layers.Dense(1, activation='sigmoid'))
lr=0.09
model9.compile(optimizer=SGD(learning_rate=lr),
              loss='binary_crossentropy',
              metrics = ['accuracy'])
model9.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_36 (Dense)            (None, 2)                 6
#
#  dense_37 (Dense)            (None, 18)                54
#
#  dense_38 (Dense)            (None, 18)                342
#
#  dense_39 (Dense)            (None, 18)                342
#
#  dense_40 (Dense)            (None, 18)                342
#
#  dense_41 (Dense)            (None, 1)                 19
#
# ...
# Total params: 1,105
# Trainable params: 1,105
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Training the Models**

# %%
history1 = model1.fit(X_train, y_train, epochs=50, batch_size=1)
# plt.figure(figsize=(14,7))
# plt.title('Loss Curve')
# plt.subplot(121)
# plt.plot(history1.history['loss'])
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.subplot(121)
# plt.plot(history1.history['accuracy'])
# plt.ylabel('accuracy')
# plt.xlabel('epoch')

# plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 4ms/step - loss: 0.6650 - accuracy: 0.6800
# Epoch 2/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4990 - accuracy: 0.7700
# Epoch 3/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4319 - accuracy: 0.8200
# Epoch 4/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3266 - accuracy: 0.8700
# Epoch 5/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2758 - accuracy: 0.9300
# Epoch 6/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2434 - accuracy: 0.9300
# Epoch 7/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2325 - accuracy: 0.9400
# Epoch 8/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2199 - accuracy: 0.9400
# Epoch 9/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2109 - accuracy: 0.9300
# Epoch 10/50
# ...

# %%
history2 = model2.fit(X_train, y_train, epochs=50, batch_size=1)
# plt.figure(figsize=(14,7))
# plt.title('Loss Curve')
# plt.subplot(121)
# plt.plot(history2.history['loss'])
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.subplot(121)
# plt.plot(history2.history['accuracy'])
# plt.ylabel('accuracy')
# plt.xlabel('epoch')

# plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 2ms/step - loss: 0.6704 - accuracy: 0.5900
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5852 - accuracy: 0.7500
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.4796 - accuracy: 0.8600
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.8200
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.8900
# Epoch 6/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2707 - accuracy: 0.9300
# Epoch 7/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3771 - accuracy: 0.8500
# Epoch 8/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1716 - accuracy: 0.9800
# Epoch 9/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1809 - accuracy: 0.9600
# Epoch 10/50
# ...

# %%
history3 = model3.fit(X_train, y_train, epochs=50, batch_size=1)
# plt.figure(figsize=(14,7))
# plt.title('Loss Curve')
# plt.subplot(121)
# plt.plot(history3.history['loss'])
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.subplot(121)
# plt.plot(history3.history['accuracy'])
# plt.ylabel('accuracy')
# plt.xlabel('epoch')

# plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 1ms/step - loss: 0.6627 - accuracy: 0.6100
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.4922 - accuracy: 0.7600
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3484 - accuracy: 0.8800
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.8700
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2838 - accuracy: 0.9200
# Epoch 6/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2716 - accuracy: 0.8900
# Epoch 7/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1842 - accuracy: 0.9300
# Epoch 8/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2669 - accuracy: 0.9500
# Epoch 9/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2251 - accuracy: 0.9400
# Epoch 10/50
# ...

# %%
history4 = model4.fit(X_train, y_train, epochs=50, batch_size=1)
# plt.figure(figsize=(14,7))
# plt.title('Loss Curve')
# plt.subplot(121)
# plt.plot(history4.history['loss'])
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.subplot(121)
# plt.plot(history4.history['accuracy'])
# plt.ylabel('accuracy')
# plt.xlabel('epoch')

# plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 1ms/step - loss: 0.6290 - accuracy: 0.6300
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.4703 - accuracy: 0.7400
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.4178 - accuracy: 0.8700
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3387 - accuracy: 0.8800
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3320 - accuracy: 0.8800
# Epoch 6/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2818 - accuracy: 0.8800
# Epoch 7/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.9200
# Epoch 8/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.9200
# Epoch 9/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9400
# Epoch 10/50
# ...

# %%
history5 = model5.fit(X_train, y_train, epochs=50, batch_size=1)
# plt.figure(figsize=(14,7))
# plt.title('Loss Curve')
# plt.subplot(121)
# plt.plot(history5.history['loss'])
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.subplot(121)
# plt.plot(history5.history['accuracy'])
# plt.ylabel('accuracy')
# plt.xlabel('epoch')

# plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 2ms/step - loss: 0.6881 - accuracy: 0.6100
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6202 - accuracy: 0.7000
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7156 - accuracy: 0.5000
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7018 - accuracy: 0.4800
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6976 - accuracy: 0.5300
# Epoch 6/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6997 - accuracy: 0.4600
# Epoch 7/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6919 - accuracy: 0.5700
# Epoch 8/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7021 - accuracy: 0.4800
# Epoch 9/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7002 - accuracy: 0.4700
# Epoch 10/50
# ...

# %%
history6 = model6.fit(X_train, y_train, epochs=50, batch_size=1)
# plt.figure(figsize=(14,7))
# plt.title('Loss Curve')
# plt.subplot(121)
# plt.plot(history6.history['loss'])
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.subplot(121)
# plt.plot(history6.history['accuracy'])
# plt.ylabel('accuracy')
# plt.xlabel('epoch')

# plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 2ms/step - loss: 0.7194 - accuracy: 0.4800
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7197 - accuracy: 0.4000
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7182 - accuracy: 0.4700
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7086 - accuracy: 0.5000
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7195 - accuracy: 0.4800
# Epoch 6/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7151 - accuracy: 0.5300
# Epoch 7/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7192 - accuracy: 0.5100
# Epoch 8/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7232 - accuracy: 0.4200
# Epoch 9/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7153 - accuracy: 0.4700
# Epoch 10/50
# ...

# %%
history7 = model7.fit(X_train, y_train, epochs=50, batch_size=1)
# plt.figure(figsize=(14,7))
# plt.title('Loss Curve')
# plt.subplot(121)
# plt.plot(history7.history['loss'])
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.subplot(121)
# plt.plot(history7.history['accuracy'])
# plt.ylabel('accuracy')
# plt.xlabel('epoch')

# plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 2ms/step - loss: 0.7353 - accuracy: 0.4500
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7119 - accuracy: 0.5100
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6554 - accuracy: 0.5700
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6005 - accuracy: 0.6700
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6234 - accuracy: 0.6400
# Epoch 6/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7008 - accuracy: 0.5200
# Epoch 7/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6937 - accuracy: 0.5100
# Epoch 8/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7131 - accuracy: 0.4900
# Epoch 9/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7043 - accuracy: 0.4900
# Epoch 10/50
# ...

# %%
history8 = model8.fit(X_train, y_train, epochs=50, batch_size=1)
# plt.figure(figsize=(14,7))
# plt.title('Loss Curve')
# plt.subplot(121)
# plt.plot(history8.history['loss'])
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.subplot(121)
# plt.plot(history8.history['accuracy'])
# plt.ylabel('accuracy')
# plt.xlabel('epoch')

# plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 2ms/step - loss: 0.7118 - accuracy: 0.5200
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7053 - accuracy: 0.4600
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7016 - accuracy: 0.4900
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6992 - accuracy: 0.4900
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7019 - accuracy: 0.4500
# Epoch 6/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5300
# Epoch 7/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6972 - accuracy: 0.5600
# Epoch 8/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.5600
# Epoch 9/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6375 - accuracy: 0.6600
# Epoch 10/50
# ...

# %%
history9 = model9.fit(X_train, y_train, epochs=50, batch_size=1)
# plt.figure(figsize=(14,7))
# plt.title('Loss Curve')
# plt.subplot(121)
# plt.plot(history9.history['loss'])
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.subplot(121)
# plt.plot(history9.history['accuracy'])
# plt.ylabel('accuracy')
# plt.xlabel('epoch')

# plt.show()
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 2ms/step - loss: 0.7231 - accuracy: 0.4700
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7235 - accuracy: 0.3900
# Epoch 3/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7124 - accuracy: 0.5000
# Epoch 4/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6984 - accuracy: 0.5300
# Epoch 5/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7077 - accuracy: 0.4500
# Epoch 6/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.7064 - accuracy: 0.4600
# Epoch 7/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6986 - accuracy: 0.5300
# Epoch 8/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6940 - accuracy: 0.5300
# Epoch 9/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6674 - accuracy: 0.5900
# Epoch 10/50
# ...

# %% [markdown]
# # **Graphs of the Result**

# %%
def plot_boundary(clf, X, Y):
    h = 0.02
    x_min, x_max = X[:,0].min() - 10*h, X[:,0].max() + 10*h
    y_min, y_max = X[:,1].min() - 10*h, X[:,1].max() + 10*h
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(5,5))
    plt.contourf(xx, yy, Z, alpha=0.25)
    plt.contour(xx, yy, Z, colors='k', linewidths=0.7)
    plt.scatter(X[:,0], X[:,1], c=Y, edgecolors='k');

# %%
plt.suptitle('Classification Comparision of the 9 Models')
plot_boundary(model1, X_train, y_train)
plt.title("Model 1") 
plot_boundary(model2, X_train, y_train)
plt.title("Model 2")
plot_boundary(model3, X_train, y_train)
plt.title("Model 3")
plot_boundary(model4, X_train, y_train)
plt.title("Model 4")
plot_boundary(model5, X_train, y_train)
plt.title("Model 5")
plot_boundary(model6, X_train, y_train)
plt.title("Model 6")
plot_boundary(model7, X_train, y_train)
plt.title("Model 7")
plot_boundary(model8, X_train, y_train)
plt.title("Model 8")
plot_boundary(model9, X_train, y_train)
plt.title("Model 9")
# Out:
# Text(0.5, 1.0, 'Model 9')

# %%
figure, axis = plt.subplots(3, 3, figsize=(16,12))
plt.suptitle('Classification Comparision of the 9 Models')
axis[0,0].plot(history1.history['loss'], label='loss')
axis[0,0].legend(loc="upper right")
axis[0,0].plot(history1.history['accuracy'], label='accuracy')
axis[0,0].legend(loc="upper right")
axis[0,0].set_title("Model 1")
axis[0,1].plot(history2.history['loss'])
axis[0,1].plot(history2.history['accuracy'])
axis[0,1].set_title("Model 2")
axis[0,2].plot(history3.history['loss'])
axis[0,2].plot(history3.history['accuracy'])
axis[0,2].set_title("Model 3")
axis[1,0].plot(history4.history['loss'])
axis[1,0].plot(history4.history['accuracy'])
axis[1,0].set_title("Model 4")
axis[1,1].plot(history5.history['loss'])
axis[1,1].plot(history5.history['accuracy'])
axis[1,1].set_title("Model 5")
axis[1,2].plot(history6.history['loss'])
axis[1,2].plot(history6.history['accuracy'])
axis[1,2].set_title("Model 6")
axis[2,0].plot(history7.history['loss'])
axis[2,0].plot(history7.history['accuracy'])
axis[2,0].set_title("Model 7")
axis[2,1].plot(history8.history['loss'])
axis[2,1].plot(history8.history['accuracy'])
axis[2,1].set_title("Model 8")
axis[2,2].plot(history9.history['loss'])
axis[2,2].plot(history9.history['accuracy'])
axis[2,2].set_title("Model 9")
# Out:
# Text(0.5, 1.0, 'Model 9')
